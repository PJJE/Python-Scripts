# %% [markdown]
# # Ciencia de Datos en Python

# %% [markdown]
# ### Hoja de Trabajo 3 - Análisis de Datos con Python

# %% [markdown]
# ### Pablo Jirón (22007786)

# %% [markdown]
# ### Marzo 19, 2023

# %% [markdown]
# Para este laboratorio deberá entregar el link de GitHub a un Notebook de Jupyter con todo el código y comentarios que considere necesario para dar solución a lo planteado, copie la pregunta en una celda de Markdown y de solución a la misma con las celdas de código de Python.

# %% [markdown]
# ### Parte 1: Numpy:
# Para los ejercicios siguiente genere el código que considere para resolver el problema que se le plantea.

# %% [markdown]
# 1) ¿Cuál es el tamaño en bytes de un array de 1000 elementos de tipo booleano?

# %%
# Importando las Bibliotecas:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Creando arreglo
array1=np.repeat(True,500)
array2=np.repeat(False,500)
array3=np.concatenate([array1,array2])
print(array3.size)
# Out:
# 1000

# %% [markdown]
# Para responder True o False (se usan los enteros 0 o 1) y cada caracter ocupa 8 Bits lo que es igual a 1 Byte; por lo tanto el array de 1000 elementos ocuparía 1000 Bytes.

# %% [markdown]
# 2) Cree un array cuyos elementos sean los enteros pares en [1,100] y en orden decreciente. Muestre los 10 últimos por pantalla.

# %%
# Arreglo de 1 a 100:
arreglo=np.linspace(2,100,50)
arreglo=np.flip(arreglo)
print(arreglo)
# Out:
# [100.  98.  96.  94.  92.  90.  88.  86.  84.  82.  80.  78.  76.  74.
#   72.  70.  68.  66.  64.  62.  60.  58.  56.  54.  52.  50.  48.  46.
#   44.  42.  40.  38.  36.  34.  32.  30.  28.  26.  24.  22.  20.  18.
#   16.  14.  12.  10.   8.   6.   4.   2.]

# %%
# Los 10 últimos en pantalla:
print(arreglo[-10:])
# Out:
# [20. 18. 16. 14. 12. 10.  8.  6.  4.  2.]

# %% [markdown]
# 3) Dado el array:
#
#     - 2 4 5 6
#     - 0 3 7 4
#     - 8 8 5 2
#     - 1 5 6 1

# %% [markdown]
# Seleccione con una instrucción el subarray de elementos:
#
#     - 0 3 7 4

# %%
matriz=np.array([[2, 4, 5, 6],
                 [0, 3, 7, 4],
                 [8, 8, 5, 2],
                 [1, 5, 6, 1]])
print(matriz[1])
# Out:
# [0 3 7 4]

# %% [markdown]
# Después, seleccione el subarray de elementos:
#
#     - 2 5
#     - 8 5

# %%
subarray1=matriz[0, [0,2]] 
subarray2=matriz[2, [1,2]]
print(subarray1)
print(subarray2)
# Out:
# [2 5]
# [8 5]

# %% [markdown]
# 4) Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9], obtenga la media aritmética de la diferencia (a-b).

# %%
a=np.array([1,4,2,7])
b=np.array([1,3,2,9])
diferencia=(a-b)
print(np.mean(diferencia))
# Out:
# -0.25

# %% [markdown]
# 5) Tengo valores de cordenadas (x, y) en las columnas del array:
#
#     - 1.33      4.5
#     - 30.0      10.7
#     - 70.2      0.5

# %%
GPS1=np.array([[1.33, 4.5],
               [30.0, 10.7],
               [70.2, 0.5]])
GPS1
# Out:
# array([[ 1.33,  4.5 ],
#        [30.  , 10.7 ],
#        [70.2 ,  0.5 ]])

# %% [markdown]
# Agregue a este array las coordenadas (37.1, -3.6). Muestre en pantalla las dimensiones del nuevo array.

# %%
nueva_coord=np.array([37.1, -3.6])
GPS1=np.append(GPS1,[nueva_coord],axis=0)
GPS1
# Out:
# array([[ 1.33,  4.5 ],
#        [30.  , 10.7 ],
#        [70.2 ,  0.5 ],
#        [37.1 , -3.6 ]])

# %%
# Dimensión de GPS1:
GPS1.shape
# Out:
# (3, 2)

# %% [markdown]
# 6) Copie el array del ejercicio anterior. Traspóngalo (. Agregue ahora dos nuevos pares de coordenadas: (10.8, 3.0) y (35.8, 12.0).

# %%
# Agregamos las nuevas coordenadas:
GPS2=GPS1
nueva_coord1=np.array([10.8,3.0])
GPS2= np.append(GPS2,[nueva_coord1],axis=0)
nueva_coord2= np.array([35.8,12.0])
GPS2= np.append(GPS2,[nueva_coord2],axis=0)
GPS2
# Out:
# array([[ 1.33,  4.5 ],
#        [30.  , 10.7 ],
#        [70.2 ,  0.5 ],
#        [10.8 ,  3.  ],
#        [35.8 , 12.  ]])

# %%
# Lo Transponemos:
GPS2_trans=GPS2.T
GPS2_trans
# Out:
# array([[ 1.33, 30.  , 70.2 , 10.8 , 35.8 ],
#        [ 4.5 , 10.7 ,  0.5 ,  3.  , 12.  ]])

# %% [markdown]
# ### Parte 2: Exploración y Minería de Datos:
# Con el dataset nucleospoblacion.csv adjunto al laboratorio, luego responda las siguientes preguntas usando pandas y matplotlib.

# %%
# Importamos el Dataset:
dataset=pd.read_csv('NucleosPoblacion.csv')
dataset
# Out:
#      FID  OBJECTID                           Texto  Poblacion  CodMun  \
# 0      0         1                         Agüimes    29431.0   35002
# 1      1         2                         Antigua    10458.0   35003
# 2      2         3                        Arrecife    58156.0   35004
# 3      3         4                          Arucas    36745.0   35006
# 4      4         5                          Gáldar    24473.0   35009
# ..   ...       ...                             ...        ...     ...
# 847  847       848             Infante Juan Manuel    14192.0   30030
# 848  848       849           Santa Maria de Gracia    13349.0   30030
# 849  849       850                    Vista Alegre    15208.0   30030
# 850  850       851  Poligono Sta M de Benquerencia    19177.0   45168
# 851  851       852                            Grao    16367.0   12040
#
#                                       Municipio  CodProvin  \
# 0                                       Agüimes         35
# ...

# %% [markdown]
# 1) ¿Cuántos Municipios tienen más de 100000 habitantes?.

# %%
municipios100mil=dataset.query('Poblacion>100000')
len(municipios100mil)
# Out:
# 62

# %% [markdown]
# 2) Realice una gráfica de barras sobre la polbación de cada ciudad, ordenela de menor a mayo y responda:

# %% [markdown]
# a. ¿Cuál es la segunda ciudad más poblada?

# %% [markdown]
# b. ¿Qué posición ocupa Granada en el ranking de las ciudades más pobladas?

# %%
municipios=dataset
plt.bar(municipios['Municipio'],municipios['Poblacion'])
plt.xticks(rotation=90)
plt.xlabel('Municipio')
plt.ylabel('Población')
plt.title('Municipios del Dataset')
plt.show()

# %% [markdown]
# 3) ¿Cuántos municipios de Extremadura tienen más de 5000 habitantes?.

# %%
Extremadura=dataset.query("Provincia=='Cáceres' or Provincia=='Badajoz'")
municipios5mil=Extremadura[Extremadura["Poblacion"]>5000]
len(municipios5mil)
# Out:
# 14

# %% [markdown]
# 4) ¿Cuál es el municipio situado más al Norte? (Usar el valor de la coordenada "Y" que representa la latitud en grados). Proporcione también la provincia a la que pertenece y su población.

# %%
muniNorte=dataset.loc[dataset['Y'].idxmax()]
municipio=muniNorte['Municipio']
provincia=muniNorte['Provincia']
poblacion=muniNorte['Poblacion']
print(municipio)
print(provincia)
print(poblacion)
# Out:
# Viveiro
# Lugo
# 16211.0

# %% [markdown]
# 5) Obtenga la media, mediana, desviación estándar, valor máximo y valor mínimo de la población de los municipios de la provincia de Granada.

# %%
Granada=dataset[dataset['Provincia']=='Granada']
Estad_Descriptiva=Granada['Poblacion'].describe()
Estad_Descriptiva
# Out:
# count        20.000000
# mean      30217.850000
# std       50355.491715
# min       10386.000000
# 25%       13146.500000
# 50%       17526.000000
# 75%       21739.750000
# max      239154.000000
# Name: Poblacion, dtype: float64

# %% [markdown]
# 6) Realice un histograma con la población de los Municipios para cada una de las provincias.

# %%
muniPob=dataset.groupby('Provincia')
for name, group in muniPob:
    plt.hist(group['Poblacion'],bins=10)
    plt.title(name)
    plt.xlabel('Población')
    plt.ylabel('Frecuencia')
    plt.show()

# %% [markdown]
# 7) Seleccione al azar cincuenta municipios diferentes de entre los diponibles en el archivo. Asegúrese de que no se repitan. ¿Luego calcule el promedio de la población y la desviación estándar de esto 50 municipios?.

# %%
muniUnicos=dataset['Municipio'].unique()
samples=pd.Series(muniUnicos).sample(n=50,random_state=1)
subset=dataset[dataset['Municipio'].isin(samples)]
MEAN=subset['Poblacion'].mean()
STD=subset['Poblacion'].std()
print(MEAN)
print(STD)
# Out:
# 31679.23076923077
# 36122.309098023514

# %% [markdown]
# 8) Dígame los nombres de los Municipios más cercano y más lejano a Madrid. Para ello debe calcular la distancia en todos ellos y Madrid. No considere a Madrid en el análisis ya que la distancia sería cero.
